# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

steps_data = pd.read_csv('steps.csv', sep = ';')
survey_data = pd.read_csv('survey.csv')

# %%
df= survey_data.merge(steps_data, on = 'id')
df.head(5)
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  7-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    3914.0    4364.0       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# ...

# %%
df.describe()
# Out:
#                id     hh_size   education      height      weight  \
# count  929.000000  929.000000  929.000000  928.000000  927.000000
# mean   465.000000    2.342304    2.530678  171.668103   72.833873
# std    268.323499    1.226129    1.274491    9.080235   25.902717
# min      1.000000    1.000000    1.000000  145.000000    6.000000
# 25%    233.000000    1.000000    1.000000  165.000000   61.000000
# 50%    465.000000    2.000000    2.000000  172.000000   71.000000
# 75%    697.000000    3.000000    4.000000  179.000000   81.000000
# max    929.000000   11.000000    5.000000  195.000000  700.000000
#
#           20-6-2013     21-6-2013     22-6-2013     23-6-2013     24-6-2013  \
# count     24.000000    243.000000    278.000000    296.000000    354.000000
# mean    3642.416667   9034.724280  10889.636691   7402.847973   8110.370056
# std     3951.910368   6412.774483   6283.204309   6733.291773   5495.536639
# ...

# %%
df['bmi']= df ['weight']/ (df ['height']/100)**2
df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  8-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    4364.0       NaN       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014        bmi
# ...

# %% [markdown]
# Onmogelijke waardes worden vervangen door NAN

# %%
df['weight']=df['weight'].replace(700,np.nan)

# %%
df['steps_mean']=df.iloc[:,9:336].mean(axis=1)
df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  6-5-2014  7-5-2014  8-5-2014  9-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...       NaN       NaN       NaN    6227.0
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
# ...

# %%
df=df[df['steps_mean']<100000]

# %%
sns.scatterplot(x="height", y="weight", data= df)
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %%
df_sub = df [['weight', 'bmi', 'steps_mean']]
sns.pairplot(df_sub)
plt.show()

# %%
corr = df_sub.corr()
corr
# Out:
#               weight       bmi  steps_mean
# weight      1.000000  0.871191   -0.085936
# bmi         0.871191  1.000000   -0.017788
# steps_mean -0.085936 -0.017788    1.000000

# %% [markdown]
# Explain linear regression in your own words:
# Namate x toeneemt stijgt y steeds met hetzelfde getal.

# %%
df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  6-5-2014  7-5-2014  8-5-2014  9-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...       NaN       NaN       NaN    6227.0
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
# ...

# %%
df_dummies = pd.get_dummies(df,columns=['city','gender','education_1'],drop_first= True)
df_dummies.head()
# Out:
#    id    age  hh_size  education  height  weight  20-6-2013  21-6-2013  \
# 0   1  25-34        4          4   178.0    98.0        NaN        NaN
# 1   2  35-44        1          3   180.0    77.0        NaN        NaN
# 2   3  25-34        2          2   180.0    83.0        NaN    11428.0
# 3   4    <25        1          1   178.0    80.0        NaN        NaN
# 4   5  25-34        3          4   167.0    61.0        NaN        NaN
#
#    22-6-2013  23-6-2013  ...    steps_mean  city_Lille  city_Lyon  \
# 0        NaN        NaN  ...  10205.521212           0          0
# 1    10473.0      705.0  ...   5687.423313           1          0
# 2    12523.0     2553.0  ...   8301.729730           0          0
# 3        NaN        NaN  ...   3633.200000           0          1
# 4        NaN        NaN  ...   5312.129630           0          0
#
#    city_Montpellier  gender_Male  education_1_High school  \
# 0                 0            1                        0
# ...

# %%
x = df[['steps_mean']]
y = df['id']

x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.3,random_state=23) #splits the data into train (70%) and test (30%) data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-faf0553febef> in <module>
#       2 y = df['id']
#       3
# ----> 4 x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.3,random_state=23) #splits the data into train (70%) and test (30%) data
#
# NameError: name 'train_test_split' is not defined
